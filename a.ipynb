# %%
path = r"C:\Users\Vinoshan\Desktop\Projects\Python\Ani-Rec\CSV"

import pandas as pd

# %%
shows = pd.read_csv(f"{path}/All-Shows.csv")

# %%
shows
# Out:
#      Unnamed: 0  Rank                                              Title  \
# 0             0     1                                  Sousou no Frieren
# 1             1     2                    Fullmetal Alchemist Brotherhood
# 2             2     3                               One Piece Fan Letter
# 3             3     4                                        Steins Gate
# 4             4     5                 Shingeki no Kyojin Season 3 Part 2
# ..          ...   ...                                                ...
# 995         995   996                                    Wan Sheng Jie 4
# 996         996   997               Kara no Kyoukai Movie 4 Garan no Dou
# 997         997   998             Kidou Senshi Gundam Senkou no Hathaway
# 998         998   999  Kuroko no Basket Movie 3 Winter Cup Tobira no ...
# 999         999  1000                  Mairimashita Iruma kun 3rd Season
#
#      Score                                                URL
# ...
